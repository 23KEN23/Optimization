# %% [markdown]
# ## THINGS TO DO
#
# ##### Add Language Constraints
# ##### Add Capacity Constraints

# %%
from gurobipy import *
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import shapefile as shp
from collections import defaultdict

# %%
UpdateMode=1

# %% [markdown]
# ### Set Parameters

# %%
M = 100000
maxOpenD = 6
maxOpenA = 2

maxDist_D = 150
maxDist_A = 350

# %% [markdown]
# ### loop

# %%
for prov in range(1,35): #35
    print(prov)
    #Get Settlement List
    #Settlements = pd.read_csv("prov_code_%s.csv"%prov,sep=",").sample(frac=0.1,replace=False)
    Settlements = pd.read_csv("prov_code_%s.csv"%prov,sep=",")
    #EXTRACT DATA
    #Get Settlement List
    #Settlements = pd.read_csv("afg_ppl_settlement_pnt.csv",sep=",")
    #Settlements=pd.read_csv("prov_code_3.csv",sep=",")
    Settlements = Settlements[["OBJECTID","LAT_Y","LON_X"]]
    #Settlements=Settlements[[0,10,11]]
    S = Settlements.shape[0]
    Settlement_List = Settlements['OBJECTID'].tolist()

    #Get District Court List
    Districts = pd.read_csv("District_Courts.csv",sep=",")
    Districts = Districts[[1,4,5]]
    D = Districts.shape[0]
    District_List = Districts['DIST_CODE'].tolist()

    #Get Appeals Court List
    Appeals = pd.read_csv("Appeals_Courts.csv",sep=",")
    Appeals = Appeals[[1,4,5]]
    A = Appeals.shape[0]
    Appeals_List = Appeals['PROV_CODE'].tolist()
    
    
    #Create Dictionaries
    Settlement_Dict = Settlements.set_index('OBJECTID').T.to_dict('list')
    District_Dict = Districts.set_index('DIST_CODE').T.to_dict('list')
    Appeals_Dict = Appeals.set_index('PROV_CODE').T.to_dict('list')

    #Create Dictionaries
    Settlement_Dict = Settlements.set_index('OBJECTID').T.to_dict('list')
    District_Dict = Districts.set_index('DIST_CODE').T.to_dict('list')
    Appeals_Dict = Appeals.set_index('PROV_CODE').T.to_dict('list')

    #Create Dictionaries
    Settlement_Dict = Settlements.set_index('OBJECTID').T.to_dict('list')
    District_Dict = Districts.set_index('DIST_CODE').T.to_dict('list')
    Appeals_Dict = Appeals.set_index('PROV_CODE').T.to_dict('list')
   
    #Create Dictionaries for District Courthouse Distances
    Dist_D = {}
    R = 6371e3
    for d in District_List:
        d_lon = District_Dict[d][0]
        d_lat = District_Dict[d][1]
        theta2 = np.radians(d_lat)


        for s in Settlement_List:
            s_lon = Settlement_Dict[s][1]
            s_lat = Settlement_Dict[s][0]
            theta1 = np.radians(s_lat)

            #Distance to District Court
            delta_theta = np.radians(d_lat - s_lat)
            delta_lambda = np.radians(d_lon - s_lon)
            a = np.sin(delta_theta/2) * np.sin(delta_theta/2) + np.cos(theta1) * np.cos(theta2) * np.sin(delta_lambda/2) * np.sin(delta_lambda/2)
            c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))

            Dist_D[s,d] = (R * c)/1000

    #Create Dictionaries for Appeals Courthouse Distances
    Dist_A = {}
    R = 6371e3
    for a in Appeals_List:
        a_lon = Appeals_Dict[a][0]
        a_lat = Appeals_Dict[a][1]
        theta3 = np.radians(a_lat)

        for s in Settlement_List:
            s_lon = Settlement_Dict[s][1]
            s_lat = Settlement_Dict[s][0]
            theta1 = np.radians(s_lat)

            #Distance to District Court
            delta_theta = np.radians(a_lat - s_lat)
            delta_lambda = np.radians(a_lon - s_lon)
            a1 = np.sin(delta_theta/2) * np.sin(delta_theta/2) + np.cos(theta1) * np.cos(theta3) * np.sin(delta_lambda/2) * np.sin(delta_lambda/2)
            c = 2 * np.arctan2(np.sqrt(a1), np.sqrt(1-a1))

            Dist_A[s,a] = (R * c)/1000
            
#######################################################################################################################

    #Create Model
    m = Model("Afghanistan")

    #Suppress output
    m.Params.OutputFlag = 1
    m.Params.LogFile="ProvinceRunOutputs/log_prov%s.log"%prov
    
    # Return value of variable
    def VarVal(var):
        if (type(var) == gurobipy.Var):
            val = var.X

        else:
            val = 0
        return val
    
    # Create d_i_j variables
    d = {}
    for i in Settlement_List:
        d[i] = {}
        for j in District_List:
            if Dist_D[i,j] < maxDist_D:
                d[i][j] = m.addVar(vtype=GRB.BINARY, name='d_%s_%s' % (i, j))
                d[i][j].start=10000
            else:
                d[i][j] = 0
    m.update()
    
    # Create d_i_j transpose dictionary 
    d_t = defaultdict(dict)
    for key, val in d.items():
        for subkey, subval in val.items():
            d_t[subkey][key] = subval
            
    # Create a_i_k variables
    a = {}
    for i in Settlement_List:
        a[i] = {}
        for k in Appeals_List:
            if Dist_A[i,k] < maxDist_A:
                a[i][k] = m.addVar(vtype=GRB.BINARY, name='a_%s_%s' % (i, k))
                a[i][k].start=0
            else:
                a[i][k] = 0
    m.update()
    
    # Create a_i_k transpose dictionary 
    a_t = defaultdict(dict)
    for key, val in a.items():
        for subkey, subval in val.items():
            a_t[subkey][key] = subval
    
    # Create c_j_k variables
    c = {}
    for j in District_List:
        c[j] = {}
        for k in Appeals_List:
            c[j][k] = m.addVar(vtype=GRB.BINARY, name='c_%s_%s' % (j, k))
            c[j][k].start=0
    m.update()
    
    # Create c_j_k transpose dictionary 
    c_t = defaultdict(dict)
    for key, val in c.items():
        for subkey, subval in val.items():
            c_t[subkey][key] = subval
            
    #Create openD variables
    openD = {}
    for j in District_List:
        openD[j] = m.addVar(vtype=GRB.BINARY, name='openD_%s' % (j))
        openD[j].start = 0
    m.update()
    
    #Create openA variables
    openA = {}
    for k in Appeals_List:
        openA[k] = m.addVar(vtype=GRB.BINARY, name='openA_%s' % (k))
        openA[k].start=0
    m.update()
    
    # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
    #CREATE CONSTRAINTS
    
    #One S -> D Assignment
    for i in Settlement_List:
        m.addConstr(quicksum(d[i][j] for j in d[i]) == 1)
    m.update()
    
    #Maximum District Courts Open
    for j in District_List:
        m.addConstr(quicksum(d_t[j][i] for i in d_t[j]) <= M * openD[j])
    m.update()
    
    #One S -> A Assignment
    for i in Settlement_List:
        m.addConstr(quicksum(a[i][k] for k in a[i]) == 1)
    m.update()

    #Maximum Appeals Courts Open
    for k in Appeals_List:
        m.addConstr(quicksum(a_t[k][i] for i in a_t[k]) <= M * openA[k])
    m.update()

    #One D -> A Assignment
    for j in District_List:
        m.addConstr(quicksum(c[j][k] for k in c[j]) == openD[j])
    m.update()
    
    #C constraints
    for k in Appeals_List:
        m.addConstr(quicksum(c[j][k] for j in District_List) <= M*openA[k])
    m.update()
    
    #Max Open Courthouse Constraints
    m.addConstr(quicksum(openD[j] for j in District_List) <= maxOpenD)
    m.update()
    
    m.addConstr(quicksum(openA[k] for k in Appeals_List) <= maxOpenA)
    m.update()
    
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
    m.setObjective(
            quicksum(   quicksum(   Dist_D[i,j]*d_t[j][i] for i in d_t[j])    for j in District_List) + \
            quicksum(   quicksum(   Dist_A[i,k]*a_t[k][i] for i in a_t[k])    for k in Appeals_List), GRB.MINIMIZE)
    m.update()
    
    #Initiate while loop
    start_time = time.time()
    violated_c = 1

    while (violated_c > 0):
        print("ADD CONSTRAINT and OPTIMIZE")
        m.update()
        m.optimize()

        violated_c = 0
        for i in Settlement_List:
            for j in District_List:
                for k in Appeals_List:
                    #Assign vars based on 0 or gurobi.Var               
                    d_val = VarVal(d[i][j])
                    a_val = VarVal(a[i][k])
                    c_val = VarVal(c[j][k])

                    #Add constraints if violated
                    if (d_val + a_val - c_val > 1):
                        violated_c = violated_c + 1
                        m.addConstr(d[i][j] + a[i][k] - c[j][k] <= 1)                 


        #m.update() 
    end_time = time.time()
    print("RUN TIME %s" %(end_time-start_time))
    m.write("ProvinceRunOutputs/out_prov%s.sol"%prov)
# Out:
# 1
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter LogFile to ProvinceRunOutputs/log_prov1.log
#    Prev: gurobi.log  Default:
# ADD CONSTRAINT and OPTIMIZE
# Optimize a model with 2906 rows, 156907 columns and 314248 nonzeros
# Variable types: 0 continuous, 156907 integer (156907 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e-01, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 366115
# Presolve removed 481 rows and 8496 columns
# Presolve time: 0.67s
# Presolved: 2425 rows, 148411 columns, 297011 nonzeros
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R0 by 1269999.000000000
#
# Variable types: 0 continuous, 148411 integer (148411 binary)
#
# Root relaxation: objective 3.056495e+04, 2082 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 30564.9547    0   34 366114.597 30564.9547  91.7%     -    1s
# H    0     0                    74053.758567 30564.9547  58.7%     -    1s
# H    0     0                    44818.073649 30564.9547  31.8%     -    1s
# H    0     0                    39041.778665 30564.9547  21.7%     -    2s
# H    0     0                    35660.858303 30564.9547  14.3%     -    3s
#      0     0 31533.5620    0  844 35660.8583 31533.5620  11.6%     -    4s
#      0     0 33666.9116    0 1825 35660.8583 33666.9116  5.59%     -    5s
#      0     0 33672.0976    0 1828 35660.8583 33672.0976  5.58%     -    6s
#      0     0 34244.3188    0 1896 35660.8583 34244.3188  3.97%     -    7s
#      0     0 34247.6939    0 1897 35660.8583 34247.6939  3.96%     -    7s
#      0     0 34422.9904    0 2058 35660.8583 34422.9904  3.47%     -    8s
#      0     0 34452.7883    0 2153 35660.8583 34452.7883  3.39%     -    8s
#      0     0 34510.3908    0 2068 35660.8583 34510.3908  3.23%     -    9s
#      0     0 34526.5401    0 1846 35660.8583 34526.5401  3.18%     -    9s
#      0     0 34560.9150    0 1833 35660.8583 34560.9150  3.08%     -   10s
#      0     0 34570.7830    0 2333 35660.8583 34570.7830  3.06%     -   10s
#      0     0 34640.7782    0 2344 35660.8583 34640.7782  2.86%     -   11s
#      0     0 34640.7782    0 2344 35660.8583 34640.7782  2.86%     -   13s
#      0     2 34640.7782    0 2344 35660.8583 34640.7782  2.86%     -   14s
#      3     6 34704.5505    2 1969 35660.8583 34704.5505  2.68%   343   15s
# *   18    10               9    34754.322443 34704.7714  0.14%   114   16s
#
# Cutting planes:
#   Cover: 86
#   Clique: 2526
#   MIR: 67
#
# Explored 27 nodes (9459 simplex iterations) in 16.74 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 6: 34754.3 35660.9 39041.8 ... 366115
# Pool objective bound 34754.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.475432244345e+04, best bound 3.475432244345e+04, gap 0.0000%
# ADD CONSTRAINT and OPTIMIZE
# Optimize a model with 3309 rows, 156907 columns and 315457 nonzeros
# Variable types: 0 continuous, 156907 integer (156907 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e-01, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 366115
# Presolve removed 481 rows and 8496 columns
# Presolve time: 0.66s
# Presolved: 2828 rows, 148411 columns, 298220 nonzeros
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R0 by 1269999.000000000
#
# Variable types: 0 continuous, 148411 integer (148411 binary)
#
# Root relaxation: objective 3.056495e+04, 2085 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 30564.9547    0   34 366114.597 30564.9547  91.7%     -    1s
# H    0     0                    36174.860983 30564.9547  15.5%     -    1s
# H    0     0                    36003.898588 30564.9547  15.1%     -    2s
# H    0     0                    34804.459392 30564.9547  12.2%     -    3s
#      0     0 32071.4985    0 1114 34804.4594 32071.4985  7.85%     -    4s
#      0     0 33787.6464    0 1644 34804.4594 33787.6464  2.92%     -    5s
#      0     0 33787.6550    0 1648 34804.4594 33787.6550  2.92%     -    5s
#      0     0 34290.5335    0 1778 34804.4594 34290.5335  1.48%     -    6s
#      0     0 34290.6587    0 1780 34804.4594 34290.6587  1.48%     -    7s
#      0     0 34413.9955    0 1896 34804.4594 34413.9955  1.12%     -    7s
# *    0     0               0    34754.322443 34754.3224  0.00%     -   10s
#
# Explored 0 nodes (11748 simplex iterations) in 10.43 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 5: 34754.3 34804.5 36003.9 ... 366115
# Pool objective bound 34754.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.475432244345e+04, best bound 3.475432244345e+04, gap 0.0000%
# ADD CONSTRAINT and OPTIMIZE
# Optimize a model with 3379 rows, 156907 columns and 315667 nonzeros
# Variable types: 0 continuous, 156907 integer (156907 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e-01, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 366115
# Presolve removed 481 rows and 8496 columns
# Presolve time: 0.60s
# Presolved: 2898 rows, 148411 columns, 298430 nonzeros
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R0 by 1269999.000000000
#
# Variable types: 0 continuous, 148411 integer (148411 binary)
#
# Root relaxation: objective 3.077777e+04, 2174 iterations, 0.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 30777.7685    0   36 366114.597 30777.7685  91.6%     -    1s
# H    0     0                    37361.362167 30777.7685  17.6%     -    1s
# H    0     0                    37156.821597 30777.7685  17.2%     -    2s
# H    0     0                    35994.041436 30777.7685  14.5%     -    3s
#      0     0 32496.6469    0 1208 35994.0414 32496.6469  9.72%     -    4s
#      0     0 32496.6469    0 1211 35994.0414 32496.6469  9.72%     -    5s
#      0     0 33734.9501    0 1624 35994.0414 33734.9501  6.28%     -    6s
#      0     0 33734.9511    0 1626 35994.0414 33734.9511  6.28%     -    6s
#      0     0 34553.5449    0 2128 35994.0414 34553.5449  4.00%     -    7s
#      0     0 34606.6716    0 2152 35994.0414 34606.6716  3.85%     -    8s
#      0     0 34786.8993    0 2482 35994.0414 34786.8993  3.35%     -    9s
# H    0     0                    35946.703270 34786.8993  3.23%     -   10s
#      0     0 34793.7527    0 2568 35946.7033 34793.7527  3.21%     -   10s
#      0     0 34917.5651    0 2668 35946.7033 34917.5651  2.86%     -   10s
#      0     0 34924.4720    0 3025 35946.7033 34924.4720  2.84%     -   11s
#      0     0 34965.3580    0 3135 35946.7033 34965.3580  2.73%     -   11s
#      0     0 34965.3580    0 3132 35946.7033 34965.3580  2.73%     -   14s
# *    0     0               0    35109.638550 35109.6385  0.00%     -   20s
#
# Explored 0 nodes (12852 simplex iterations) in 20.20 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 6: 35109.6 35946.7 35994 ... 366115
# Pool objective bound 35109.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.510963854996e+04, best bound 3.510963854996e+04, gap 0.0000%
# ADD CONSTRAINT and OPTIMIZE
# Optimize a model with 3380 rows, 156907 columns and 315670 nonzeros
# Variable types: 0 continuous, 156907 integer (156907 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e-01, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 366115
# Presolve removed 481 rows and 8496 columns
# Presolve time: 0.58s
# Presolved: 2899 rows, 148411 columns, 298433 nonzeros
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R0 by 1269999.000000000
#
# Variable types: 0 continuous, 148411 integer (148411 binary)
#
# Root relaxation: objective 3.077777e+04, 2174 iterations, 0.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 30777.7685    0   36 366114.597 30777.7685  91.6%     -    1s
# H    0     0                    40937.054322 30777.7685  24.8%     -    1s
# H    0     0                    40021.569057 30777.7685  23.1%     -    2s
# H    0     0                    35785.296542 30777.7685  14.0%     -    3s
#      0     0 32361.2412    0 1211 35785.2965 32361.2412  9.57%     -    3s
#      0     0 32361.2412    0 1214 35785.2965 32361.2412  9.57%     -    4s
#      0     0 34246.2310    0 1701 35785.2965 34246.2310  4.30%     -    5s
#      0     0 34247.6951    0 1704 35785.2965 34247.6951  4.30%     -   11s
#      0     0 34667.3732    0 2804 35785.2965 34667.3732  3.12%     -   12s
#      0     0 34678.1482    0 2837 35785.2965 34678.1482  3.09%     -   13s
#      0     0 34870.9295    0 2876 35785.2965 34870.9295  2.56%     -   14s
#      0     0 34878.0066    0 2894 35785.2965 34878.0066  2.54%     -   14s
#      0     0 34969.6790    0 2734 35785.2965 34969.6790  2.28%     -   14s
#      0     0 34971.5920    0 2287 35785.2965 34971.5920  2.27%     -   15s
#      0     0 35014.1179    0 2171 35785.2965 35014.1179  2.16%     -   15s
# *    0     0               0    35109.872943 35109.8729  0.00%     -   18s
#
# Explored 0 nodes (13622 simplex iterations) in 18.69 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 5: 35109.9 35785.3 40021.6 ... 366115
# Pool objective bound 35109.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.510987294317e+04, best bound 3.510987294317e+04, gap 0.0000%
# RUN TIME 279.413000107
# 2
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter LogFile to ProvinceRunOutputs/log_prov2.log
#    Prev: gurobi.log  Default:
# ADD CONSTRAINT and OPTIMIZE
# Optimize a model with 2132 rows, 99200 columns and 198834 nonzeros
# Variable types: 0 continuous, 99200 integer (99200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [9e-02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 164241
# Presolve removed 519 rows and 9144 columns
# Presolve time: 0.29s
# Presolved: 1613 rows, 90056 columns, 180281 nonzeros
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R0 by 1139999.000000000
#
# Variable types: 0 continuous, 90056 integer (90056 binary)
#
# Root relaxation: objective 1.468643e+04, 1284 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 14686.4301    0   10 164240.512 14686.4301  91.1%     -    0s
# H    0     0                    14872.070511 14686.4301  1.25%     -    0s
#      0     0 14686.4301    0   10 14872.0705 14686.4301  1.25%     -    1s
#      0     0 14833.2973    0  226 14872.0705 14833.2973  0.26%     -    1s
#      0     0     cutoff    0      14872.0705 14872.0705  0.00%     -    1s
#
# Cutting planes:
#   Cover: 14
#   Clique: 699
#   MIR: 13
#
# Explored 0 nodes (1756 simplex iterations) in 1.85 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 14872.1 164241
# Pool objective bound 14872.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.487207051053e+04, best bound 1.487207051053e+04, gap 0.0000%
# ADD CONSTRAINT and OPTIMIZE
# Optimize a model with 2763 rows, 99200 columns and 200727 nonzeros
# Variable types: 0 continuous, 99200 integer (99200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [9e-02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 153609
# Presolve removed 519 rows and 9144 columns
# Presolve time: 0.35s
# Presolved: 2244 rows, 90056 columns, 182174 nonzeros
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R0 by 1139999.000000000
#
# Variable types: 0 continuous, 90056 integer (90056 binary)
#
# Root relaxation: objective 1.470858e+04, 1507 iterations, 0.09 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 14708.5842    0  104 153608.518 14708.5842  90.4%     -    0s
# H    0     0                    14908.044800 14708.5842  1.34%     -    0s
# H    0     0                    14872.070511 14708.5842  1.10%     -    1s
#      0     0 14834.7158    0  399 14872.0705 14834.7158  0.25%     -    1s
#      0     0     cutoff    0      14872.0705 14872.0705  0.00%     -    1s
#
# Explored 0 nodes (3514 simplex iterations) in 2.00 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 14872.1 14908 153609
# Pool objective bound 14872.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.487207051053e+04, best bound 1.487207051053e+04, gap 0.0000%
# RUN TIME 64.0090000629
# 3
# Parameter OutputFlag unchanged
#    Value: 1  Min: 0  Max: 1  Default: 1
# Changed value of parameter LogFile to ProvinceRunOutputs/log_prov3.log
#    Prev: gurobi.log  Default:
# ADD CONSTRAINT and OPTIMIZE
# Optimize a model with 2912 rows, 136632 columns and 273698 nonzeros
# Variable types: 0 continuous, 136632 integer (136632 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [2e-01, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 354834
# Presolve removed 479 rows and 8496 columns
# Presolve time: 0.52s
# Presolved: 2433 rows, 128136 columns, 256463 nonzeros
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R0 by 999999.000000000
#
# Variable types: 0 continuous, 128136 integer (128136 binary)
#
# Root relaxation: objective 3.626333e+04, 2084 iterations, 0.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 36263.3346    0   30 354833.799 36263.3346  89.8%     -    0s
# H    0     0                    65494.211887 36263.3346  44.6%     -    2s
# H    0     0                    45766.766990 36263.3346  20.8%     -    2s
# H    0     0                    39521.215100 36263.3346  8.24%     -    3s
#      0     0 37305.2536    0  556 39521.2151 37305.2536  5.61%     -    3s
#      0     0 38450.6994    0 1031 39521.2151 38450.6994  2.71%     -    4s
#      0     0 38452.0319    0 1031 39521.2151 38452.0319  2.71%     -    5s
#      0     0 38900.4998    0 1310 39521.2151 38900.4998  1.57%     -    5s
#      0     0 38902.9334    0 1315 39521.2151 38902.9334  1.56%     -    6s
#      0     0 39104.5582    0 1643 39521.2151 39104.5582  1.05%     -    6s
# *    0     0               0    39413.251444 39413.2514  0.00%     -    9s
#
# Explored 0 nodes (10986 simplex iterations) in 9.46 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 5: 39413.3 39521.2 45766.8 ... 354834
# Pool objective bound 39413.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.941325144398e+04, best bound 3.941325144398e+04, gap 0.0000%
# ADD CONSTRAINT and OPTIMIZE
# Optimize a model with 3088 rows, 136632 columns and 274226 nonzeros
# Variable types: 0 continuous, 136632 integer (136632 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [2e-01, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+00]
# Found heuristic solution: objective 354834
# Presolve removed 479 rows and 8496 columns
# Presolve time: 0.53s
# Presolved: 2609 rows, 128136 columns, 256991 nonzeros
#
# MIP start did not produce a new incumbent solution
# MIP start violates constraint R0 by 999999.000000000
#
# Variable types: 0 continuous, 128136 integer (128136 binary)
#
# Root relaxation: objective 3.626333e+04, 2086 iterations, 0.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 36263.3346    0   30 354833.799 36263.3346  89.8%     -    0s
# H    0     0                    64702.677295 36263.3346  44.0%     -    1s
# H    0     0                    47078.139560 36263.3346  23.0%     -    1s
# H    0     0                    44667.647703 36263.3346  18.8%     -    1s
# H    0     0                    40948.265012 36263.3346  11.4%     -    2s
#      0     0 36797.6337    0  365 40948.2650 36797.6337  10.1%     -    3s
#      0     0 38351.2020    0 1317 40948.2650 38351.2020  6.34%     -    4s
#      0     0 38351.2074    0 1318 40948.2650 38351.2074  6.34%     -    4s
#      0     0 38894.7596    0 1529 40948.2650 38894.7596  5.01%     -    5s
# H    0     0                    39521.215100 38894.7596  1.59%     -    6s
#      0     0 38897.7138    0 1517 39521.2151 38897.7138  1.58%     -    6s
#      0     0 39117.4859    0 1825 39521.2151 39117.4859  1.02%     -    6s
# *    0     0               0    39413.251444 39413.2514  0.00%     -    9s
#
# Explored 0 nodes (11186 simplex iterations) in 9.23 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count
#      0     0 65947.9688    0 4692 69760.7517 65947.9688  5.47%     -   17s
#      0     0 66453.1988    0 4995 69760.7517 66453.1988  4.74%     -   19s
#      0     0 66475.0363    0 4989 69760.7517 66475.0363  4.71%     -   20s
#      0     0 66717.3599    0 5000 69760.7517 66717.3599  4.36%     -   22s
#      0     0 66742.1908    0 4899 69760.7517 66742.1908  4.33%     -   23s
#      0     0 66890.1241    0 5297 69760.7517 66890.1241  4.11%     -   25s
#      0     0 66890.1241    0 5297 69760.7517 66890.1241  4.11%     -   28s
# H    0     2                    67496.514020 66890.1241  0.90%     -   62s
#      0     2 66890.1241    0 5297 67496.5140 66890.1241  0.90%     -   62s
# Exception KeyboardInterrupt in 'gurobipy.logcallbackstub' ignored
#      3     3 66911.6788    2 5102 67496.5140 66911.6788  0.87%   123   65s
#     38    31 67210.0124   18 3922 67496.5140 66932.2256  0.84%   154   70s
#     78    55 67258.0863   37 3683 67496.5140 66932.2256  0.84%   125   75s
#    158   117     cutoff   61      67496.5140 66951.3573  0.81%  88.2   80s
# Exception KeyboardInterrupt in 'gurobipy.logcallbackstub' ignored
#    186   125     cutoff   11      67496.5140 66987.6216  0.75%   108   86s
#    282   207 67472.4964   29 3695 67496.5140 66987.6216  0.75%  86.9   90s
#    379   283     cutoff   12      67496.5140 67077.1807  0.62%  73.4   97s
#    396   282     cutoff   10      67496.5140 67110.1266  0.57%  84.7  100s
#    412   281 67246.0252   16 3647 67496.5140 67146.8717  0.52%  91.8  105s
#    455   311 67353.8508   42 3050 67496.5140 67146.8717  0.52%  94.8  110s
#    544   360 67390.6755   86 2366 67496.5140 67146.8717  0.52%  87.3  116s
#    588   383 67399.8785   15 3533 67496.5140 67208.3036  0.43%  90.3  121s
#    642   425 67436.6632   56 1652 67496.5140 67208.3036  0.43%  87.6  125s
#    720   484 67319.5702   12 3155 67496.5140 67213.2981  0.42%  85.0  130s
#    751   506 67253.0598   37 5297 67496.5140 67213.2981  0.42%  83.7  140s

# %% [markdown]
# ### Output Solution

# %% [markdown]
# ###  Plotting

# %% [markdown]
# #### DOUT

# %%
# DOUT - District Assignments

DOUT = pd.DataFrame.from_dict({(i,j): VarVal(d[i][j]) 
                           for i in d.keys() 
                           for j in d[i].keys()},
                           orient='index')

Settlements_DOUT = [i[0] for i in DOUT.index]
Districts_DOUT = [i[1] for i in DOUT.index]

DOUT['Settlement'] = Settlements_DOUT
DOUT['DistrictCourts'] = Districts_DOUT

DOUT = DOUT[DOUT[0] == 1.0]

# %% [markdown]
# #### AOUT

# %%
#AOUT - Appeals Assignments

AOUT = pd.DataFrame.from_dict({(i,j): VarVal(a[i][j]) 
                           for i in a.keys() 
                           for j in a[i].keys()},
                           orient='index')

Settlements_AOUT = [i[0] for i in AOUT.index]
Appeals_AOUT = [i[1] for i in AOUT.index]

AOUT['Settlement'] = Settlements_AOUT
AOUT['AppealsCourts'] = Appeals_AOUT

AOUT = AOUT[AOUT[0] == 1.0]

# %% [markdown]
# #### COUT

# %%
#COUT - Appeals Assignments

COUT = pd.DataFrame.from_dict({(i,j): VarVal(c[i][j]) 
                           for i in c.keys() 
                           for j in c[i].keys()},
                           orient='index')

Districts_COUT = [i[0] for i in COUT.index]
Appeals_COUT = [i[1] for i in COUT.index]

COUT['DistrictCourts'] = Districts_COUT
COUT['AppealsCourts'] = Appeals_COUT

COUT = COUT[COUT[0] == 1.0]

# %% [markdown]
# #### Plot all Locations

# %%
plt.scatter(Settlements['LON_X'],Settlements['LAT_Y'])
plt.scatter(Districts['LON_X'],Districts['LAT_Y'], color='Red', marker = 's')
plt.scatter(Appeals['LON_X'],Appeals['LAT_Y'], color='Green', marker = '^')
plt.show()

# %% [markdown]
# #### Plotting Assignments

# %%
#Drawing Lines
plt.figure(figsize=(14,14))

#Plotting Points    
plt.scatter(Settlements['LON_X'],Settlements['LAT_Y'])
plt.scatter(Districts['LON_X'],Districts['LAT_Y'], color='Red', marker = 's',s=25)
plt.scatter(Appeals['LON_X'],Appeals['LAT_Y'], color='Green', marker = '^',s = 400)

for index,row in DOUT.iterrows():
    s = row['Settlement'] 
    d = row['DistrictCourts']
    #Get District number that Settlement is linked to
    Dist = Districts.loc[Districts['DIST_CODE'] == d]
    Sett = Settlements.loc[Settlements['OBJECTID'] == s]
    X = [Sett.iloc[0,2],Dist.iloc[0,1]]
    Y = [Sett.iloc[0,1],Dist.iloc[0,2]]
    plt.scatter(Dist.iloc[0,1],Dist.iloc[0,2], color='Orange', marker = 's',s = 100)
    plt.plot(X,Y,zorder=1, color="Black")



#axes = plt.gca()
#axes.set_xlim([68.2,70])
#axes.set_ylim([34,35.5])

plt.show()

# %%
#Draw Lines
plt.figure(figsize=(14,14))

for index,row in COUT.iterrows():
    d = row['DistrictCourts'] 
    a = row['AppealsCourts']

    Dist = Districts.loc[Districts['DIST_CODE'] == d]
    App = Appeals.loc[Appeals['PROV_CODE'] == a]

    X = [Dist.iloc[0,1],App.iloc[0,1]]
    Y = [Dist.iloc[0,2],App.iloc[0,2]]

    plt.plot(X,Y,zorder=1, color="Black")
    
clr = cm.rainbow(np.linspace(0, 1, D))
for a in range(A):
    X = Appeals.iloc[a,1]
    Y = Appeals.iloc[a,2]
    plt.scatter(X,Y, color="Green", marker = '^')
    
for index,row in DOUT.iterrows():   
    d = row['DistrictCourts'] 
    Dist = Districts.loc[Districts['DIST_CODE'] == d]
    X = Dist.iloc[0,1]
    Y = Dist.iloc[0,2]
    c = Dist.index[0]
    plt.scatter(X,Y, color=clr[c], marker = 's')
    
for index,row in DOUT.iterrows():
    s = row['Settlement'] 
    d = row['DistrictCourts']
    #Get District number that Settlement is linked to
    Dist = Districts.loc[Districts['DIST_CODE'] == d]
    Sett = Settlements.loc[Settlements['OBJECTID'] == s]

    c = Dist.index[0]
    X = Sett.iloc[0,2]                                                     
    Y = Sett.iloc[0,1]
    plt.scatter(X,Y, color=clr[c])
          
#axes = plt.gca()
#axes.set_xlim([68.2,70])
#axes.set_ylim([34,35.5])

sf = shp.Reader("Afghanistan_Districts","rb")
for shape in sf.shapeRecords():
    x = [i[0] for i in shape.shape.points[:]]
    y = [i[1] for i in shape.shape.points[:]]
    plt.plot(x,y,color='k',linewidth=0.1)
plt.show()

# %% [markdown]
# ##
