# %% [markdown]
# # THINGS TO DO TO THIS FILE
# #### 1) Reapply Linking Constraints
# #### 2) Fix Objective to original
# #### 3) Implement Iterative optimization
# ##### - solve without linking constraints
# ##### - find linking constraints that are violated
# ##### - include linking violated linking constraints
# ##### - re-optimize
# ##### - terminate when optimal or infeasible

# %%
from gurobipy import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from collections import defaultdict

# %% [markdown]
# ### Set Parameters

# %%
M = 10000
maxOpenD = 50
maxOpenA = 20
maxDistance = 10000

#maxPopD- max capacity of each district court
#maxPopA - max capacity of each appeals court

#xS,yS 
#xD,yD
#xA,yA

#langS
#langD
#langA


#param d{i in Settlements,j in DistrictCourts} 
#	:= sqrt( (xS[i]-xD[j])^2 + (yS[i]-yD[j])^2); #distance between settlement and district court
#param a{i in Settlements,k in AppealsCourts} 
#	:= sqrt( (xA[k]-xS[i])^2 + (yA[k]-yS[i])^2); #distance between district court and appeals court

# %% [markdown]
# ### Extract Data

# %%
#Get Settlement List
Settlements = pd.read_csv("afg_ppl_settlement_pnt.csv",sep=",")
Settlements = Settlements[[0,10,11]]
S = Settlements.shape[0]
Settlement_List = Settlements['OBJECTID'].tolist()

#Get District Court List
Districts = pd.read_csv("District_Courts.csv",sep=",")
Districts = Districts[[1,4,5]]
D = Districts.shape[0]
District_List = Districts['DIST_CODE'].tolist()

#Get Appeals Court List
Appeals = pd.read_csv("Appeals_Courts.csv",sep=",")
Appeals = Appeals[[1,4,5]]
A = Appeals.shape[0]
Appeals_List = Appeals['PROV_CODE'].tolist()

# %% [markdown]
# #### Create Data Subset for Settlements

# %% [markdown]
# #### ------------------------------------------------

# %%
Settlements = Settlements.sample(frac = 0.01, replace = False)
S = Settlements.shape[0]
Settlement_List = Settlements['OBJECTID'].tolist()

# %% [markdown]
# ####  ------------------------------------------------

# %%
#Create Dictionaries
Settlement_Dict = Settlements.set_index('OBJECTID').T.to_dict('list')
District_Dict = Districts.set_index('DIST_CODE').T.to_dict('list')
Appeals_Dict = Appeals.set_index('PROV_CODE').T.to_dict('list')

# %%
#Create Dictionaries for District Courthouse Distances

Dist_D = {}

R = 6371e3


for d in District_List:
    d_lon = District_Dict[d][0]
    d_lat = District_Dict[d][1]
    φ2 = np.radians(d_lat)


    for s in Settlement_List:
        s_lon = Settlement_Dict[s][1]
        s_lat = Settlement_Dict[s][0]
        φ1 = np.radians(s_lat)
        
        #Distance to District Court
        Δφ = np.radians(d_lat - s_lat)
        Δλ = np.radians(d_lon - s_lon)
        a = np.sin(Δφ/2) * np.sin(Δφ/2) + np.cos(φ1) * np.cos(φ2) * np.sin(Δλ/2) * np.sin(Δλ/2)
        c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
        
        Dist_D[s,d] = (R * c)/1000

# %%
#Create Dictionaries for Appeals Courthouse Distances

Dist_A = {}

R = 6371e3

for a in Appeals_List:
    a_lon = Appeals_Dict[a][0]
    a_lat = Appeals_Dict[a][1]
    φ3 = np.radians(a_lat)

    for s in Settlement_List:
        s_lon = Settlement_Dict[s][1]
        s_lat = Settlement_Dict[s][0]
        φ1 = np.radians(s_lat)
        
        #Distance to District Court
        Δφ = np.radians(a_lat - s_lat)
        Δλ = np.radians(a_lon - s_lon)
        a1 = np.sin(Δφ/2) * np.sin(Δφ/2) + np.cos(φ1) * np.cos(φ3) * np.sin(Δλ/2) * np.sin(Δλ/2)
        c = 2 * np.arctan2(np.sqrt(a1), np.sqrt(1-a1))
        
        Dist_A[s,a] = (R * c)/1000

# %%
#Create Dictionaries for Appeals Courthouse Distances

Dist_C = {}

R = 6371e3

for a in Appeals_List:
    a_lon = Appeals_Dict[a][0]
    a_lat = Appeals_Dict[a][1]
    φ3 = np.radians(a_lat)

    for d in District_List:
        d_lon = District_Dict[d][0]
        d_lat = District_Dict[d][1]
        φ2 = np.radians(d_lat)
        
        #Distance to District Court
        Δφ = np.radians(a_lat - d_lat)
        Δλ = np.radians(a_lon - d_lon)
        a2 = np.sin(Δφ/2) * np.sin(Δφ/2) + np.cos(φ2) * np.cos(φ3) * np.sin(Δλ/2) * np.sin(Δλ/2)
        c = 2 * np.arctan2(np.sqrt(a2), np.sqrt(1-a2))
        
        Dist_C[d,a] = (R * c)/1000

# %% [markdown]
# ### Create Model

# %%
#Create Model
m = Model("Afghanistan")

# %% [markdown]
# ### Create Variables

# %% [markdown]
# ##### d_ij

# %%
# Create d_i_j variables
d = {}
for i in Settlement_List:
    d[i] = {}
    for j in District_List:
        if Dist_D[i,j] < 150:
            d[i][j] = m.addVar(vtype=GRB.BINARY, name='d_%s_%s' % (i, j))
m.update()

# %%
# Create d_i_j transpose dictionary 
d_t = defaultdict(dict)
for key, val in d.items():
    for subkey, subval in val.items():
        d_t[subkey][key] = subval

# %% [markdown]
# ##### a_ik

# %%
 # Create a_i_k variables
a = {}
for i in Settlement_List:
    a[i] = {}
    for k in Appeals_List:
        if Dist_A[i,k] < 350:
            a[i][k] = m.addVar(vtype=GRB.BINARY, name='a_%s_%s' % (i, k))
m.update()

# %%
# Create a_i_k transpose dictionary 
a_t = defaultdict(dict)
for key, val in a.items():
    for subkey, subval in val.items():
        a_t[subkey][key] = subval

# %% [markdown]
# ##### c_jk

# %%
# Create c_j_k variables
c = {}
for j in District_List:
    c[j] = {}
    for k in Appeals_List:
        c[j][k] = m.addVar(vtype=GRB.BINARY, name='c_%s_%s' % (j, k))
m.update()

# %%
# Create c_j_k transpose dictionary 
c_t = defaultdict(dict)
for key, val in c.items():
    for subkey, subval in val.items():
        c_t[subkey][key] = subval

# %% [markdown]
# ##### openD

# %%
#Create openD variables
openD = {}
for j in District_List:
    openD[j] = m.addVar(vtype=GRB.BINARY, name='openD_%s' % (j))
m.update()

# %% [markdown]
# ##### openA

# %%
#Create openA variables
openA = {}
for k in Appeals_List:
    openA[k] = m.addVar(vtype=GRB.BINARY, name='openA_%s' % (k))
m.update()

# %% [markdown]
# ### Create Constraints

# %% [markdown]
# ##### One Courhouse Assignment Constraints

# %%
#One S -> D Assignment
for i in Settlement_List:
    m.addConstr(quicksum(d[i][j] for j in d[i]) == 1)
m.update()

# %%
#One S -> A Assignment
for i in Settlement_List:
    m.addConstr(quicksum(a[i][k] for k in a[i]) == 1)
m.update()

# %%
#One D -> A Assignment
for j in District_List:
    m.addConstr(quicksum(c[j][k] for k in c[j]) == openD[j])
m.update()

# %%
# <gurobi.Model MIP instance Afghanistan: 90433 constrs, 6239918 vars, Parameter changes: LogFile=gurobi.log>

# %% [markdown]
# ##### Max Open Courthouse Constraints

# %%
#Maximum District Courts Open
for j in District_List:
    m.addConstr(quicksum(d_t[j][i] for i in d_t[j]) <= M * openD[j])
    
m.addConstr(quicksum(openD[j] for j in District_List) <= maxOpenD)

m.update()

# %%
#Maximum Appeals Courts Open
for k in Appeals_List:
    m.addConstr(quicksum(a_t[k][i] for i in a_t[k]) <= M * openA[k])
    
m.addConstr(quicksum(openA[k] for k in Appeals_List) <= maxOpenA)

m.update()

# %%
#C constraints
for k in Appeals_List:
    m.addConstr(quicksum(c[j][k] for j in District_List) <= M*openA[k])

m.update()

# %%
m
# Out:
# <gurobi.Model MIP instance Afghanistan: 1770 constrs, 46356 vars, Parameter changes: LogFile=gurobi.log>

# %%
# <gurobi.Model MIP instance Afghanistan: 90869 constrs, 3,186,780 vars, Parameter changes: LogFile=gurobi.log>

# %% [markdown]
# ##### Linking Constraints - NEED FIXING

# %%
#Linking Constraints
for i in Settlement_List:
    for j in District_List:
        for k in Appeals_List:
            m.addConstr(d[i,j] + a[i,k] - c[j,k] <= 1)

m.update()

# %% [markdown]
# ### Set Objective Function

# %% [markdown]
# #### D_ij and C_jk

# %%
 m.setObjective(
        quicksum(   quicksum(   Dist_D[i,j]*d_t[j][i] for i in d_t[j])    for j in District_List) + \
        quicksum(   quicksum(   Dist_C[j,k]*c_t[k][j] for j in c_t[k])    for k in Appeals_List), GRB.MINIMIZE)
m.update()

# %% [markdown]
# #### D_ij

# %%
m.setObjective(
        quicksum(   quicksum(   Dist_D[i,j]*d_t[j][i] for i in d_t[j])    for j in District_List), GRB.MINIMIZE)
m.update()

# %% [markdown]
# ### Optimize

# %%
m.optimize()
# Out:
# Optimize a model with 1770 rows, 46356 columns and 93146 nonzeros
# Variable types: 0 continuous, 46356 integer (46356 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [3e-01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
# Found heuristic solution: objective 44281.1
# Presolve removed 3 rows and 15 columns
# Presolve time: 0.16s
# Presolved: 1767 rows, 46341 columns, 93115 nonzeros
# Found heuristic solution: objective 29513.646785
# Variable types: 0 continuous, 46341 integer (46341 binary)
#
# Root relaxation: objective 5.947995e+03, 1424 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 5947.99467    0  408 29513.6468 5947.99467  79.8%     -    0s
# H    0     0                    20395.430736 5947.99467  70.8%     -    0s
#      0     0 7611.35397    0  511 20395.4307 7611.35397  62.7%     -    1s
# H    0     0                    20299.212037 7611.35397  62.5%     -    1s
#      0     0 7720.67201    0  539 20299.2120 7720.67201  62.0%     -    1s
#      0     0 9617.92540    0  806 20299.2120 9617.92540  52.6%     -    1s
# H    0     0                    19908.072901 9617.92540  51.7%     -    1s
#      0     0 9690.97577    0  844 19908.0729 9690.97577  51.3%     -    1s
#      0     0 10663.2298    0 1012 19908.0729 10663.2298  46.4%     -    1s
# H    0     0                    19715.302439 10663.2298  45.9%     -    2s
#      0     0 10729.3420    0  974 19715.3024 10729.3420  45.6%     -    2s
#      0     0 11433.1314    0 1148 19715.3024 11433.1314  42.0%     -    2s
#      0     0 11501.5110    0 1044 19715.3024 11501.5110  41.7%     -    2s
#      0     0 12019.7831    0 1148 19715.3024 12019.7831  39.0%     -    2s
#      0     0 12044.4730    0 1128 19715.3024 12044.4730  38.9%     -    2s
#      0     0 12385.7903    0 1158 19715.3024 12385.7903  37.2%     -    3s
#      0     0 12423.9677    0 1174 19715.3024 12423.9677  37.0%     -    3s
#      0     0 12652.7842    0 1156 19715.3024 12652.7842  35.8%     -    3s
# H    0     0                    18356.726446 12652.7842  31.1%     -    3s
#      0     0 12660.8716    0 1216 18356.7264 12660.8716  31.0%     -    3s
#      0     0 12865.7990    0 1163 18356.7264 12865.7990  29.9%     -    3s
#      0     0 12895.3252    0 1210 18356.7264 12895.3252  29.8%     -    3s
#      0     0 13011.8554    0 1233 18356.7264 13011.8554  29.1%     -    3s
#      0     0 13011.8554    0 1233 18356.7264 13011.8554  29.1%     -    4s
# H    0     2                    18024.306658 13011.8554  27.8%     -    4s
#      0     2 13011.8554    0 1233 18024.3067 13011.8554  27.8%     -    4s
#      3     6 13026.2763    2 1230 18024.3067 13026.2763  27.7%   253    5s
# H   27    28                    17777.147690 13045.4291  26.6%  38.6    5s
# H   55    55                    17721.011247 13045.4291  26.4%  24.7    5s
# H   87    88                    17665.341514 13045.4291  26.2%  18.4    6s
# H  211   214                    17664.071588 13045.4291  26.1%  14.0    8s
# H  240   240                    17638.548960 13045.4291  26.0%  13.3    9s
# H  271   273                    16295.536083 13045.4291  19.9%  13.5    9s
#    309   310 13354.4796  142  460 16295.5361 13045.4291  19.9%  13.9   10s
# H  370   369                    15961.206395 13045.4291  18.3%  13.6   10s
# H  605   596                    14403.662211 13045.4291  9.43%  15.1   12s
# H  624   613                    14148.794096 13045.4291  7.80%  16.2   12s
# H  665   560                    13785.618652 13052.5393  5.32%  16.9   13s
#    753   629 13116.9629   33 1233 13785.6187 13052.5393  5.32%  16.8   15s
# *  754   598              14    13520.786991 13520.7870  0.00%  16.8   15s
#
# Explored 754 nodes (29839 simplex iterations) in 15.99 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 13520.8 13785.6 14148.8 ... 17721
# Pool objective bound 13520.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.352078699095e+04, best bound 1.352078699095e+04, gap 0.0000%

# %%
#Dual steepest edge pivoting

# %% [markdown]
# ### Output Solution

# %%
m.write("out.sol")

# %% [markdown]
# ###  Plotting

# %% [markdown]
# #### DOUT

# %%
# DOUT - District Assignments

DOUT = pd.DataFrame.from_dict({(i,j): d[i][j].X 
                           for i in d.keys() 
                           for j in d[i].keys()},
                           orient='index')

Settlements_DOUT = [i[0] for i in DOUT.index]
Districts_DOUT = [i[1] for i in DOUT.index]

DOUT['Settlement'] = Settlements_DOUT
DOUT['DistrictCourts'] = Districts_DOUT

DOUT = DOUT[DOUT[0] == 1.0]

# %% [markdown]
# #### AOUT

# %%
#AOUT - Appeals Assignments

AOUT = pd.DataFrame.from_dict({(i,j): a[i][j].X 
                           for i in a.keys() 
                           for j in a[i].keys()},
                           orient='index')

Settlements_AOUT = [i[0] for i in AOUT.index]
Appeals_AOUT = [i[1] for i in AOUT.index]

AOUT['Settlement'] = Settlements_AOUT
AOUT['AppealsCourts'] = Appeals_AOUT

AOUT = AOUT[AOUT[0] == 1.0]

# %% [markdown]
# #### COUT

# %%
#COUT - Appeals Assignments

COUT = pd.DataFrame.from_dict({(i,j): c[i][j].X 
                           for i in c.keys() 
                           for j in c[i].keys()},
                           orient='index')

Districts_COUT = [i[0] for i in COUT.index]
Appeals_COUT = [i[1] for i in COUT.index]

COUT['DistrictCourts'] = Districts_COUT
COUT['AppealsCourts'] = Appeals_COUT

COUT = COUT[COUT[0] == 1.0]

# %% [markdown]
# #### Plot all Locations

# %%
plt.scatter(Settlements['LON_X'],Settlements['LAT_Y'])
plt.scatter(Districts['LON_X'],Districts['LAT_Y'], color='Red', marker = 's')
plt.scatter(Appeals['LON_X'],Appeals['LAT_Y'], color='Green', marker = '^')
plt.show()

# %% [markdown]
# #### Plotting Assignments

# %%
#Drawing Lines
plt.figure(figsize=(14,14))

#Plotting Points    
plt.scatter(Settlements['LON_X'],Settlements['LAT_Y'])
plt.scatter(Districts['LON_X'],Districts['LAT_Y'], color='Red', marker = 's',s=25)
plt.scatter(Appeals['LON_X'],Appeals['LAT_Y'], color='Green', marker = '^',s = 400)

for index,row in DOUT.iterrows():
    s = row['Settlement'] 
    d = row['DistrictCourts']
    #Get District number that Settlement is linked to
    Dist = Districts.loc[Districts['DIST_CODE'] == d]
    Sett = Settlements.loc[Settlements['OBJECTID'] == s]
    X = [Sett.iloc[0,2],Dist.iloc[0,1]]
    Y = [Sett.iloc[0,1],Dist.iloc[0,2]]
    plt.scatter(Dist.iloc[0,1],Dist.iloc[0,2], color='Orange', marker = 's',s = 100)
    plt.plot(X,Y,zorder=1, color="Black")



#axes = plt.gca()
#axes.set_xlim([68.2,70])
#axes.set_ylim([34,35.5])

plt.show()

# %%
#Draw Lines
plt.figure(figsize=(14,14))

for index,row in COUT.iterrows():
    d = row['DistrictCourts'] 
    a = row['AppealsCourts']

    Dist = Districts.loc[Districts['DIST_CODE'] == d]
    App = Appeals.loc[Appeals['PROV_CODE'] == a]

    X = [Dist.iloc[0,1],App.iloc[0,1]]
    Y = [Dist.iloc[0,2],App.iloc[0,2]]

    plt.plot(X,Y,zorder=1, color="Black")
    
clr = cm.rainbow(np.linspace(0, 1, D))
for a in range(A):
    X = Appeals.iloc[a,1]
    Y = Appeals.iloc[a,2]
    plt.scatter(X,Y, color="Green", marker = '^')
    
for index,row in DOUT.iterrows():   
    d = row['DistrictCourts'] 
    Dist = Districts.loc[Districts['DIST_CODE'] == d]
    X = Dist.iloc[0,1]
    Y = Dist.iloc[0,2]
    c = Dist.index[0]
    plt.scatter(X,Y, color=clr[c], marker = 's')
    
for index,row in DOUT.iterrows():
    s = row['Settlement'] 
    d = row['DistrictCourts']
    #Get District number that Settlement is linked to
    Dist = Districts.loc[Districts['DIST_CODE'] == d]
    Sett = Settlements.loc[Settlements['OBJECTID'] == s]

    c = Dist.index[0]
    X = Sett.iloc[0,2]                                                     
    Y = Sett.iloc[0,1]
    plt.scatter(X,Y, color=clr[c])
          
#axes = plt.gca()
#axes.set_xlim([68.2,70])
#axes.set_ylim([34,35.5])

plt.show()

# %%
Dist = Districts.loc[Districts['DIST_CODE'] == 103]
Dist

# %%
DOUT

# %%
testy = DOUT[DOUT["Settlement"]==8790]

# %%
testy

# %%
testy2 = testy.iloc[0,2]

# %%
testy2

# %%
Settlements.loc[23192]

# %%
for i in index,row in DOUT.iterrows():
    s = row['Settlement'] 
    d = row['DistrictCourts']

# %%
Dist = Districts[Districts['DIST_CODE'] == 1505.0]

# %%
Dist

# %%
Dist.iloc[0,1]

# %%
Settlements

# %%
Settlements

# %%
quicksum(   quicksum(   Dist_D[i,j]*d_t[i,j] for i in d_t[j])    for j in District_List) + \
        quicksum(   quicksum(   Dist_A[i,k]*a_t[i,k] for i in a_t[k])    for k in Appeals_List)

# %%
quicksum(Dist_D[i,101]*d_t[i,101] for i in d_t[101])

# %%
for index,row in COUT.iterrows():
    d = row['DistrictCourts'] 
    a = row['AppealsCourts']
    print(Dist_A[s,a])

# %%
for index,row in AOUT.iterrows():
    s = row['Settlement'] 
    a = row['AppealsCourts']
    print(Dist_A[s,a])

# %%
AOUT

# %%
Settlement_List

# %%
COUT

# %%
AOUT

# %%
DOUT
